# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data=pd.read_csv("train.csv")

# %%
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
test_data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train_data.shape
# Out:
# (1460, 81)

# %%
pd.pandas.set_option('display.max_rows',None)

# %%
train_data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
train_data.isnull().sum().sum()
# Out:
# 7829

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# as we can see a lot of columns have less than 70 percent data so we should drop them

# %%
null_per=(train_data.isnull().sum())/(train_data.shape[0])*100
null_per
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
# Street            0.000000
# Alley            93.767123
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType       59.726027
# MasVnrArea        0.547945
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.534247
# BsmtCond          2.534247
# BsmtExposure      2.602740
# BsmtFinType1      2.534247
# ...

# %%
drop_columns=null_per[null_per>5].keys()
drop_columns
# Out:
# Index(['LotFrontage', 'Alley', 'MasVnrType', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC',
#        'Fence', 'MiscFeature'],
#       dtype='object')

# %%
df_dropped=train_data.drop(columns=drop_columns)
df_dropped.shape
# Out:
# (1460, 69)

# %%
df_dropped=df_dropped.drop(columns=['Id'],axis=1)

# %%
df_dropped.isnull().sum().sum()
# Out:
# 196

# %%
df=df_dropped.dropna()

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df_dropped.shape
# Out:
# (1460, 68)

# %%
# now checking null values using heatmap
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.select_dtypes(include=['int64', 'float64']).columns #this is to know which columns are numerical
# Out:
# Index(['MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#        'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars',
#        'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
# num_var=(['MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'])

# plt.figure(figsize=(25,25))
# for i, var in enumerate(num_var):
#     plt.subplot(9,4,i+1)
#     sns.displot(df[var], kind='kde')

# %%
cat_var=df.select_dtypes(include=['object']).columns
cat_var
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional',
#        'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
df['MSZoning'].value_counts()
# Out:
# MSZoning
# RL         1111
# RM          214
# FV           62
# RH           15
# C (all)      10
# Name: count, dtype: int64

# %%
sns.countplot(x=df['MSZoning'], data=df, hue=df['MSZoning'], palette=["#fee090", "#fdae61", "#4575b4","#d73027", "#a50026"])
# Out:
# <Axes: xlabel='MSZoning', ylabel='count'>

# %%
df['EnclosedPorch'].value_counts()
# Out:
# EnclosedPorch
# 0      1209
# 112      15
# 96        6
# 216       5
# 120       5
# 144       5
# 192       5
# 252       4
# 116       4
# 156       4
# 102       3
# 150       3
# 184       3
# 126       3
# 176       3
# 40        3
# 128       3
# 228       3
# 164       3
# 236       2
# 160       2
# 34        2
# 108       2
# 168       2
# 32        2
# 154       2
# 80        2
# 115       2
# 244       2
# 158       2
# 84        2
# 240       2
# 100       2
# 264       2
# 137       2
# 36        2
# 234       2
# 205       2
# 114       2
# 202       2
# 180       2
# 39        2
# 77        2
# 224       2
# 301       1
# 20        1
# 170       1
# 19        1
# 174       1
# 226       1
# 138       1
# 94        1
# 48        1
# 318       1
# 194       1
# 68        1
# 254       1
# 230       1
# 275       1
# 185       1
# 50        1
# 220       1
# 214       1
# 81        1
# 198       1
# 190       1
# 286       1
# 162       1
# 123       1
# 42        1
# ...

# %%
df['PoolArea'].value_counts()
# Out:
# PoolArea
# 0      1405
# 512       1
# 648       1
# 576       1
# 555       1
# 480       1
# 519       1
# 738       1
# Name: count, dtype: int64

# %%
# Check how many columns are Numerical
# numerical_column=[]
# for i in df.columns:
#   if df[i].dtype!='object':
#     numerical_column.append(i)

# %%
# columns_to_be_removed=[]

# for i in train_data.columns:
#   if train_data.loc[df[i]=="value"].shape[0]<800:
#    columns_to_be_removed.append(i)

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope Neighborhood  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 0    Inside       Gtl      CollgCr  ...             0         0           0
# 1       FR2       Gtl      Veenker  ...             0         0           0
# 2    Inside       Gtl      CollgCr  ...             0         0           0
# 3    Corner       Gtl      Crawfor  ...           272         0           0
# 4       FR2       Gtl      NoRidge  ...             0         0           0
#
#   PoolArea  MiscVal  MoSold  YrSold  SaleType SaleCondition SalePrice
# ...

# %%
num_data=df.drop(columns=cat_var, axis=1)

# %%
# num_data

# %%
num_data.shape
# Out:
# (1412, 35)

# %%
num_data.isnull().sum().sum()
# Out:
# 0

# %%
#now fitting one prototype model
sns.heatmap(num_data.corr(), linewidths=0.2)
# Out:
# <Axes: >

# %%
num_data.columns
# Out:
# Index(['MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#        'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars',
#        'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
num_data.tail(7)
# Out:
#       MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 1453          20    17217            5            5       2006          2006
# 1454          20     7500            7            5       2004          2005
# 1455          60     7917            6            5       1999          2000
# 1456          20    13175            6            6       1978          1988
# 1457          70     9042            7            9       1941          2006
# 1458          20     9717            5            6       1950          1996
# 1459          20     9937            5            6       1965          1965
#
#       MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  WoodDeckSF  \
# 1453         0.0           0           0       1140  ...          36
# 1454         0.0         410           0        811  ...           0
# 1455         0.0           0           0        953  ...           0
# 1456       119.0         790         163        589  ...         349
# ...

# %%
for i in num_data.columns:
    y=num_data['SalePrice'].corr(num_data[i])
    print(f"Corr is:", y)
# Out:
# Corr is: -0.08228134656900954
# Corr is: 0.2648025578251416
# Corr is: 0.7867645427228941
# Corr is: -0.09356711859234726
# Corr is: 0.5187358492222691
# Corr is: 0.5002659488611415
# Corr is: 0.4745254656011144
# Corr is: 0.36884876682611173
# Corr is: -0.02019631136197727
# Corr is: 0.18895898088829932
# Corr is: 0.6110839004748737
# Corr is: 0.6147530051654264
# Corr is: 0.3179480820807383
# Corr is: -0.02842792003373671
# Corr is: 0.7110797668447889
# Corr is: 0.2087563046658745
# Corr is: -0.022092791776834236
# Corr is: 0.5756037364112182
# Corr is: 0.27014489320854734
# Corr is: 0.17017377668178177
# Corr is: -0.10574279330558853
# Corr is: 0.5455395195947095
# Corr is: 0.4629372050599591
# Corr is: 0.6418250974661107
# Corr is: 0.6210951042044007
# Corr is: 0.3173610436812342
# Corr is: 0.3049721965426083
# Corr is: -0.13434194816095996
# Corr is: 0.047039781012907046
# Corr is: 0.10820807491167209
# Corr is: 0.0927756846428513
# Corr is: -0.013287051788185681
# ...

# %%
#now we have to drop those columns which shows negative correlation with salesprice
columns_to_be_removed=[]
for i in num_data.columns:
    y=num_data['SalePrice'].corr(num_data[i])
    if (y<=0.10):
        columns_to_be_removed.append(i)

# %%
columns_to_be_removed
# Out:
# ['MSSubClass',
#  'OverallCond',
#  'BsmtFinSF2',
#  'LowQualFinSF',
#  'BsmtHalfBath',
#  'KitchenAbvGr',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold']

# %%
final_data=num_data.drop(columns=
 ['MSSubClass',
 'OverallCond',
 'BsmtFinSF2',
 'LowQualFinSF',
 'BsmtHalfBath',
 'KitchenAbvGr',
 'EnclosedPorch',
 '3SsnPorch',
 'ScreenPorch',
 'PoolArea',
 'MiscVal',
 'MoSold',
 'YrSold'],axis=1)

# %%
final_data.shape
# Out:
# (1412, 22)

# %%
final_data.head()
# Out:
#    LotArea  OverallQual  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# 0     8450            7       2003          2003       196.0         706
# 1     9600            6       1976          1976         0.0         978
# 2    11250            7       2001          2002       162.0         486
# 3     9550            7       1915          1970         0.0         216
# 4    14260            8       2000          2000       350.0         655
#
#    BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  ...  FullBath  HalfBath  \
# 0        150          856       856       854  ...         2         1
# 1        284         1262      1262         0  ...         2         0
# 2        434          920       920       866  ...         2         1
# 3        540          756       961       756  ...         1         0
# 4        490         1145      1145      1053  ...         2         1
#
#    BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageCars  GarageArea  WoodDeckSF  \
# ...

# %%
sns.heatmap(final_data.corr())
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
from xgboost import XGBRegressor

# %%
X=final_data.drop(columns=['SalePrice'], axis=1)
Y=final_data['SalePrice']

# %%
x_train, x_test, y_train, y_test= train_test_split(X, Y, test_size=0.33, random_state=2)

# %%
print(x_train.shape, x_test.shape)
# Out:
# (946, 21) (466, 21)

# %% [markdown]
# ## Fitting a LinearRegression model

# %%
lr=LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
print(f" the R2 is:", r2_score(y_pred, y_test))
# Out:
#  the R2 is: 0.7458068374107512

# %% [markdown]
# # Fitting Ridge, Lasso, ElasticNet

# %%
from sklearn.linear_model import Ridge, Lasso, ElasticNet

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
#transforming train and test 
x_train_scaled= scaler.transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
#converting numpy arrays to dataframe again
x_train_scaled=pd.DataFrame(x_train_scaled, columns=x_train.columns)
x_test_scaled=pd.DataFrame(x_test_scaled, columns=x_test.columns)

# %%
#fitting ridge
reg=Ridge(alpha=0.9)
reg.fit(x_train_scaled, y_train)
y_pred=reg.predict(x_test_scaled)
print(f" the R2 is:", r2_score(y_pred, y_test))
# Out:
#  the R2 is: 0.7457201546917201

# %%
#fitting lasso
reg=Lasso(alpha=0.05)
reg.fit(x_train_scaled, y_train)
y_pred=reg.predict(x_test_scaled)
print(f" the R2 is:", r2_score(y_pred, y_test))
# Out:
#  the R2 is: 0.7458063512526505

# %%
reg=ElasticNet(alpha=0.0025, l1_ratio=0.5)
reg.fit(x_train_scaled, y_train)
y_pred=reg.predict(x_test_scaled)
print(f" the R2 is:", r2_score(y_pred, y_test))
# Out:
#  the R2 is: 0.745692304279638
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.888e+09, tolerance: 5.831e+08
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# # Decision Tree

# %%
dt=DecisionTreeRegressor(max_depth=8, min_samples_split=5)

# %%
dt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=8, min_samples_split=5)

# %%
y_pred=dt.predict(x_test)
print(f" the R2 is:", r2_score(y_pred, y_test))
# Out:
#  the R2 is: 0.7747675031043686

# %% [markdown]
# # Randomforest

# %%
rf=RandomForestRegressor()

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=rf.predict(x_test)
print(f" the R2 is:", r2_score(y_pred, y_test))
# Out:
#  the R2 is: 0.8616655361470725

# %% [markdown]
# # GBM

# %%
gbm=GradientBoostingRegressor()

# %%
gbm.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred= gbm.predict(x_test)
print(f" the R2 is:", r2_score(y_pred, y_test))
# Out:
#  the R2 is: 0.8798000239602384

# %% [markdown]
# # XGB

# %%
xgb= XGBRegressor(max_depth=8, n_estimators=100)

# %%
xgb.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=8, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred=xgb.predict(x_test)
print(f" the R2 is:", r2_score(y_pred, y_test))
# Out:
#  the R2 is: 0.8499510608917421

# %%
# importing cross_val to improve accuracy
from sklearn.model_selection import cross_val_score

# %%
# model=XGBRegressor(objective= "reg:squarederror")

# %%
# scores= cross_val_score(model, X, Y, scoring="neg_mean_squared_error", cv=10)
# scores

# %%
# rmse=np.sqrt(-scores)
# rmse

# %% [markdown]
# # Trying attributes combination

# %%
num_data.head()
# Out:
#    MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0          60     8450            7            5       2003          2003
# 1          20     9600            6            8       1976          1976
# 2          60    11250            7            5       2001          2002
# 3          70     9550            7            5       1915          1970
# 4          60    14260            8            5       2000          2000
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  WoodDeckSF  \
# 0       196.0         706           0        150  ...           0
# 1         0.0         978           0        284  ...         298
# 2       162.0         486           0        434  ...           0
# 3         0.0         216           0        540  ...           0
# 4       350.0         655           0        490  ...         192
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# ...

# %%
new_num_data= num_data['WoodDeckSF'] +	num_data['OpenPorchSF'] + num_data['EnclosedPorch']+num_data['3SsnPorch']+ num_data['ScreenPorch']+ num_data['PoolArea']

# %%
new_data=pd.DataFrame(new_num_data)

# %%
new_data.columns=['total_area']

# %%
new_data.head()
# Out:
#    total_area
# 0          61
# 1         298
# 2          42
# 3         307
# 4         276

# %%
# new_data

# %%
df=pd.concat([num_data, new_data], axis=1)

# %%
df.shape
# Out:
# (1412, 36)

# %%
df.head()
# Out:
#    MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0          60     8450            7            5       2003          2003
# 1          20     9600            6            8       1976          1976
# 2          60    11250            7            5       2001          2002
# 3          70     9550            7            5       1915          1970
# 4          60    14260            8            5       2000          2000
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  OpenPorchSF  \
# 0       196.0         706           0        150  ...           61
# 1         0.0         978           0        284  ...            0
# 2       162.0         486           0        434  ...           42
# 3         0.0         216           0        540  ...           35
# 4       350.0         655           0        490  ...           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
df=df.drop(columns=['WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',  'ScreenPorch', 'PoolArea'], axis=1)

# %%
df.shape
# Out:
# (1412, 30)

# %%
df.head()
# Out:
#    MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0          60     8450            7            5       2003          2003
# 1          20     9600            6            8       1976          1976
# 2          60    11250            7            5       2001          2002
# 3          70     9550            7            5       1915          1970
# 4          60    14260            8            5       2000          2000
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  KitchenAbvGr  \
# 0       196.0         706           0        150  ...             1
# 1         0.0         978           0        284  ...             1
# 2       162.0         486           0        434  ...             1
# 3         0.0         216           0        540  ...             1
# 4       350.0         655           0        490  ...             1
#
#    TotRmsAbvGrd  Fireplaces  GarageCars  GarageArea  MiscVal  MoSold  YrSold  \
# ...

# %%
for i in df.columns:
    y=df['SalePrice'].corr(df[i])
    print(f"Corr is:", y)
# Out:
# Corr is: -0.08228134656900954
# Corr is: 0.2648025578251416
# Corr is: 0.7867645427228941
# Corr is: -0.09356711859234726
# Corr is: 0.5187358492222691
# Corr is: 0.5002659488611415
# Corr is: 0.4745254656011144
# Corr is: 0.36884876682611173
# Corr is: -0.02019631136197727
# Corr is: 0.18895898088829932
# Corr is: 0.6110839004748737
# Corr is: 0.6147530051654264
# Corr is: 0.3179480820807383
# Corr is: -0.02842792003373671
# Corr is: 0.7110797668447889
# Corr is: 0.2087563046658745
# Corr is: -0.022092791776834236
# Corr is: 0.5756037364112182
# Corr is: 0.27014489320854734
# Corr is: 0.17017377668178177
# Corr is: -0.10574279330558853
# Corr is: 0.5455395195947095
# Corr is: 0.4629372050599591
# Corr is: 0.6418250974661107
# Corr is: 0.6210951042044007
# Corr is: -0.013287051788185681
# Corr is: 0.04175365408942411
# Corr is: -0.023361233549827155
# Corr is: 1.0
# Corr is: 0.3809371911943467

# %%
columns_to_be_kept=[]
for i in df.columns:
    if ((df['SalePrice'].corr(df[i]))<=0.2):
        columns_to_be_kept.append(i)

# %%
columns_to_be_kept
# Out:
# ['MSSubClass',
#  'OverallCond',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'LowQualFinSF',
#  'BsmtHalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'MiscVal',
#  'MoSold',
#  'YrSold']

# %%
final_df=df.drop(columns= [
 'MSSubClass',
 'OverallCond',
 'BsmtFinSF2',
 'BsmtUnfSF',
 'LowQualFinSF',
 'BsmtHalfBath',
 'BedroomAbvGr',
 'KitchenAbvGr',
 'MiscVal',
 'MoSold',
 'YrSold'], axis=1)

# %%
final_df.shape
# Out:
# (1412, 19)

# %%
X=final_df.drop(columns=['SalePrice'], axis=1)
Y= final_df['SalePrice']

# %%
x_train, x_test, y_train, y_test= train_test_split(X, Y, test_size=0.33, random_state=2)

# %%
#using linearRegression model
reg= LinearRegression()

# %%
reg.fit(x_train, y_train)
y_pred= reg.predict(x_test)
print(f"R2 score is:", r2_score(y_pred, y_test))
# Out:
# R2 score is: 0.7425925296528023

# %%
#randomforest
rf_new=RandomForestRegressor()

# %%
rf_new.fit(x_train, y_train)
y_pred=rf_new.predict(x_test)
print(f"R2 score is:", r2_score(y_pred, y_test))
# Out:
# R2 score is: 0.871597136206627

# %%
#GBM
gbm=GradientBoostingRegressor(n_estimators=200)
gbm.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(n_estimators=200)

# %%
y_pred=gbm.predict(x_test)
print(f"R2 score is:", r2_score(y_pred, y_test))
# Out:
# R2 score is: 0.885111161890108
